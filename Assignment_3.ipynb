# %% [markdown]
# ### Assignment 3

# %%
#Importing required library 
import pandas as pd

# %%
#reading the dataset
df = pd.read_csv('Absenteeism_data_2.txt')

# %%
#Determing data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Information about the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         700 non-null    int64
#  1   Reason for Absence         700 non-null    int64
#  2   Date                       700 non-null    object
#  3   Transportation Expense     700 non-null    int64
#  4   Distance to Work           700 non-null    int64
#  5   Age                        700 non-null    int64
#  6   Daily Work Load Average    700 non-null    float64
#  7   Body Mass Index            700 non-null    int64
#  8   Education                  700 non-null    int64
#  9   Children                   700 non-null    int64
#  10  Pets                       700 non-null    int64
#  11  Absenteeism Time in Hours  700 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 65.8+ KB

# %%
df.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  11                  26  07/07/2015                     289
# 1  36                   0  14/07/2015                     118
# 2   3                  23  15/07/2015                     179
# 3   7                   7  16/07/2015                     279
# 4  11                  23  23/07/2015                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
#    Children  Pets  Absenteeism Time in Hours
# 0         2     1                          4
# ...

# %%
df.tail()
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 695                22   40                  237.656               22
# 696                26   28                  237.656               24
# 697                16   28                  237.656               25
# 698                16   32                  237.656               25
# 699                31   40                  237.656               25
#
#      Education  Children  Pets  Absenteeism Time in Hours
# 695          2         2     0                          8
# ...

# %%
#drop column ID
df = df.drop(['ID'], axis = 1)

# %%
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
#drop column Age
df = df.drop(['Age'], axis = 1)

# %%
df
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
#max reason for absence
df['Reason for Absence'].max()
# Out:
# 28

# %%
#Min reason for absence
df['Reason for Absence'].min()
# Out:
# 0

# %%
#Row with smallest reason of absence
df.nsmallest(1, ['Reason for Absence'])
# Out:
#    Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 1                   0  14/07/2015                     118                13
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 1                  239.554               31          1         1     0
#
#    Absenteeism Time in Hours
# 1                          0

# %%
#Row with largest reason of absence
df.nlargest(1, ['Reason for Absence'])
# Out:
#     Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 23                  28  14/08/2015                     260                50
#
#     Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 23                  205.917               23          1         4     0
#
#     Absenteeism Time in Hours
# 23                          4

# %%
#length of column reason for absence
len(df['Reason for Absence'])
# Out:
# 700

# %%
#data types of all columns
df.dtypes
# Out:
# Reason for Absence             int64
# Date                          object
# Transportation Expense         int64
# Distance to Work               int64
# Daily Work Load Average      float64
# Body Mass Index                int64
# Education                      int64
# Children                       int64
# Pets                           int64
# Absenteeism Time in Hours      int64
# dtype: object

# %%
#line plot of reason for absence against absenteeism time
df.plot.line(x= 'Reason for Absence', y = 'Absenteeism Time in Hours')

# %%
#Scatter plot of distance against absenteeism time
df.plot.scatter(x= 'Distance to Work', y = 'Absenteeism Time in Hours')

# %%
df.plot.box(x= 'Distance to Work', y = 'Absenteeism Time in Hours')
